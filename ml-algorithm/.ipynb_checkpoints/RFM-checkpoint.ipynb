# %% [markdown]
# RFM(Recency, Frequency, Monetary)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
import warnings

# %%
warnings.filterwarnings("ignore")
df = pd.read_excel("Online Retail.xlsx")

# %% [markdown]
# # Data preprocessing

# %%
data = df

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
# InvoiceNo      541909 non-null object
# StockCode      541909 non-null object
# Description    540455 non-null object
# Quantity       541909 non-null int64
# InvoiceDate    541909 non-null datetime64[ns]
# UnitPrice      541909 non-null float64
# CustomerID     406829 non-null float64
# Country        541909 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
data.loc[(df.UnitPrice<0)]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
data.loc[(data.Quantity<0)][:5]
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom

# %%
data.isnull().mean()*100
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.268311
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     24.926694
# Country         0.000000
# dtype: float64

# %%
data = data[pd.notnull(data['CustomerID'])]

# %%
data = data[data.Quantity > 0]

# %%
data = data[data.UnitPrice > 0]

# %%
data.isnull().mean()
# Out:
# InvoiceNo      0.0
# StockCode      0.0
# Description    0.0
# Quantity       0.0
# InvoiceDate    0.0
# UnitPrice      0.0
# CustomerID     0.0
# Country        0.0
# dtype: float64

# %%
filtered_data = data[['Country','CustomerID']].drop_duplicates()

# %%
filtered_data.Country.value_counts()[:10].plot(kind='bar')

# %%
uk_data=data[data.Country=='United Kingdom']

# %%
uk_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354321 entries, 0 to 541893
# Data columns (total 8 columns):
# InvoiceNo      354321 non-null object
# StockCode      354321 non-null object
# Description    354321 non-null object
# Quantity       354321 non-null int64
# InvoiceDate    354321 non-null datetime64[ns]
# UnitPrice      354321 non-null float64
# CustomerID     354321 non-null float64
# Country        354321 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 24.3+ MB

# %%
uk_data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  354321.000000  354321.000000  354321.000000
# mean       12.013795       2.963994   15552.486392
# std       189.267956      17.862655    1594.527150
# min         1.000000       0.001000   12346.000000
# 25%         2.000000       1.250000   14194.000000
# 50%         4.000000       1.950000   15522.000000
# 75%        12.000000       3.750000   16931.000000
# max     80995.000000    8142.750000   18287.000000

# %%
uk_data = uk_data[['CustomerID','InvoiceDate','InvoiceNo','Quantity','UnitPrice']]

# %%
uk_data['TotalPrice'] = uk_data['Quantity'] * uk_data['UnitPrice']

# %%
uk_data['InvoiceDate'].min(),uk_data['InvoiceDate'].max()
# Out:
# (Timestamp('2010-12-01 08:26:00'), Timestamp('2011-12-09 12:49:00'))

# %%
import datetime as dt
PRESENT = dt.datetime(2011,12,10)
uk_data['InvoiceDate'] = pd.to_datetime(uk_data['InvoiceDate'])

# %%
uk_data.head()
# Out:
#    CustomerID         InvoiceDate InvoiceNo  Quantity  UnitPrice  TotalPrice
# 0     17850.0 2010-12-01 08:26:00    536365         6       2.55       15.30
# 1     17850.0 2010-12-01 08:26:00    536365         6       3.39       20.34
# 2     17850.0 2010-12-01 08:26:00    536365         8       2.75       22.00
# 3     17850.0 2010-12-01 08:26:00    536365         6       3.39       20.34
# 4     17850.0 2010-12-01 08:26:00    536365         6       3.39       20.34

# %%
rfm_table = uk_data.groupby('CustomerID').agg({'InvoiceDate': lambda date: (PRESENT - date.max()).days,
                                        'InvoiceNo': lambda num: len(num),
                                        'TotalPrice': lambda price: price.sum()})

# %%
rfm_table.columns
# Out:
# Index(['InvoiceDate', 'InvoiceNo', 'TotalPrice'], dtype='object')

# %%
rfm_table.columns=['monetary','frequency','recency']

# %%
rfm_table['recency'] = rfm_table['recency'].astype(int)
rfm_table['frequency'] = rfm_table['frequency'].astype(int)
rfm_table['recency'] = rfm_table['recency'].astype(int)

# %%
a = ['monetary','frequency','recency']
for col in a:
    fig, ax = plt.subplots(figsize=(12,3))
    sns.distplot(rfm[col])
    ax.set_title('Distribution %s' % col)
    plt.show()

# %%
rfm['r_quartile'] = pd.qcut(rfm['recency'], 4, [1, 2, 3, 4])
rfm['f_quartile'] = pd.qcut(rfm['frequency'], 4, [4, 3, 2, 1])
rfm['m_quartile'] = pd.qcut(rfm['monetary'], 4, [4, 3, 2, 1])
rfm.head()
# Out:
#             monetary  frequency  recency r_quartile f_quartile m_quartile  \
# CustomerID
# 12346.0          325          2        0          1          4          1
# 12747.0            2        103     4196          4          1          4
# 12748.0            0       4642    29072          4          1          4
# 12749.0            3        231     3868          4          1          4
# 12820.0            3         59      942          3          2          4
#
#             RFM_Score  Labels
# CustomerID
# 12346.0           2.0       0
# 12747.0           3.0       0
# 12748.0           3.0       2
# 12749.0           3.0       0
# 12820.0           3.0       0

# %%
rfm['RFM_Score'] = round(rfm[['r_quartile','f_quartile','m_quartile']].sum(axis=1) / 3, 1)
rfm.head()
# Out:
#             monetary  frequency  recency r_quartile f_quartile m_quartile  \
# CustomerID
# 12346.0          325          2        0          1          4          1
# 12747.0            2        103     4196          4          1          4
# 12748.0            0       4642    29072          4          1          4
# 12749.0            3        231     3868          4          1          4
# 12820.0            3         59      942          3          2          4
#
#             RFM_Score  Labels  RFM_analize
# CustomerID
# 12346.0           2.0       0            2
# 12747.0           3.0       0            3
# 12748.0           3.0       2            3
# 12749.0           3.0       0            3
# 12820.0           3.0       0            3

# %%
rfm["RFM_Score"].unique()
# Out:
# array([2. , 3. , 2.3, 3.3, 2.7, 1.7, 3.7, 1.3, 4. ])

# %%
print("very high customers: ",len(rfm[rfm['RFM_Score'] < 2]))
print("high customers",len(rfm[(rfm['RFM_Score'] >= 2) & (rfm['RFM_Score'] < 3)]))
print("medium customers",len(rfm[(rfm['RFM_Score'] >= 3) & (rfm['RFM_Score'] < 4)]))
print("lost customers",len(rfm[rfm['RFM_Score'] == 4]))
# Out:
# very high customers:  233
# high customers 2639
# medium customers 1076
# lost customers 2

# %%
# def rfmAnalize(x):
#     if x < 2:
#         return 1
#     elif x >= 2 and x < 3:
#         return 2
#     elif x >= 3 and x < 4:
#         return 3
#     else: 
#         return 4

# %%
# rfm["RFM_analize"] = rfm["RFM_Score"].apply(rfmAnalize)

# %%
# sns.scatterplot(rfm['frequency'], rfm['recency'], hue=rfm['RFM_analize'], 
#                 palette=sns.color_palette('hls', 4))
# plt.title('RFM analize 4 Clusters')
# plt.show()

# %%
## K-means
# 4 cluster
from sklearn.cluster import KMeans
km = KMeans(n_clusters=4).fit(rfm)

rfm['Labels'] = km.labels_
#plt.figure(figsize=(12, 8))
sns.scatterplot(rfm['frequency'], rfm['recency'], hue=rfm['Labels'], 
                palette=sns.color_palette('hls', 4))
plt.title('KMeans avec 4 Clusters')
plt.show()

# %%
rfm
# Out:
#             monetary  frequency  recency r_quartile f_quartile m_quartile  \
# CustomerID
# 12346.0          325          2        0          1          4          1
# 12747.0            2        103     4196          4          1          4
# 12748.0            0       4642    29072          4          1          4
# 12749.0            3        231     3868          4          1          4
# 12820.0            3         59      942          3          2          4
# 12821.0          214          6       92          1          4          1
# 12822.0           70         47      918          3          2          2
# 12823.0           74          5     1759          4          4          2
# 12824.0           59         25      397          2          3          2
# 12826.0            2         94     1468          3          2          4
# 12827.0            5         25      430          2          3          4
# 12828.0            2         56     1018          3          2          4
# 12829.0          322         12      253          1          4          1
# 12830.0           37         39     6748          4          3          3
# 12831.0          262          9      215          1          4          1
# 12832.0           32         27      383          2          3          3
# 12833.0          145         24      417          2          3          1
# 12834.0          282         18      312          2          3          1
# 12836.0           59        175     2612          4          1          2
# 12837.0          173         12      134          1          4          1
# 12838.0           33        123      683          3          1          3
# 12839.0            2        316     5583          4          1          4
# 12840.0          143        116     2714          4          1          2
# 12841.0            4        439     3876          4          1          4
# 12842.0           70         34     1118          3          3          2
# 12843.0           65        108     1680          4          1          2
